# %%
import jsonlines
with jsonlines.open('test.json') as reader:
    for obj in reader:
        obj

# %%
obj
# Out:
# {'room_name': 'test',
#  'black_cards': [{'card_id': 5,
#    'text': 'card text',
#    'icon': 'deck icon',
#    'deck': 'deck name',
#    'pick': 1},
#   {'card_id': 15,
#    'text': 'testtext _ asd _',
#    'icon': 'asd',
#    'deck': 'nonexistent',
#    'pick': 2},
#   {'card_id': 16,
#    'text': 'Hogyan vesztettem el a szüzességem?',
#    'icon': 'hungarian',
#    'deck': 'hungarian',
#    'pick': 1},
#   {'card_id': 17,
#    'text': 'Miért nem jön álom a szememre?',
#    'icon': 'hungarian',
#    'deck': 'hungarian',
#    'pick': 1}],
#  'white_cards': [{'card_id': 38,
#    'text': 'A Danone görög joghurtos pornószínésznők.',
#    'icon': 'hungarian',
#    'deck': 'hungarian'},
#   {'card_id': 39,
#    'text': 'Öregecske japán fickók.',
#    'icon': 'hungarian',
#    'deck': 'hungarian'},
#   {'card_id': 40,
#    'text': 'Ingyenes kóstoló.',
#    'icon': 'hungarian',
#    'deck': 'hungarian'},
#   {'card_id': 41,
#    'text': 'Ösztrogén.',
#    'icon': 'hungarian',
# ...
